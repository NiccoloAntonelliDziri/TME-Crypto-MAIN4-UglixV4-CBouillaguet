# %%
import requests
import json

url = "http://m1.tme-crypto.fr:8888/"
headers = {
    'Content-Type': 'application/json',
}

# %% [markdown]
# Item affiché sur le tableau a l'atrium:
#
# Normalement affiche: `{"jsonrpc": "2.0", "id": 737, "result": "TELEPORT_MODULE"}`

# %%
data = {
    "jsonrpc": "2.0",
    "method": "item.name",
    "params": {"world_id": "aff2c7c107f445ea3b5f17fbdd894386", "item":"4c2d59f902b1a1dd8f62f9526153d447"},
    "id": 737
}
response = requests.post(url, headers=headers, data=json.dumps(data))
print(response.text)
# Out:
# {"jsonrpc": "2.0", "id": 737, "error": {"code": 1, "message": "Value error", "data": "Unbound item handle"}}

# %%
data = {
    "jsonrpc": "2.0",
    "method": "item.find-by-name",
    "params": {"world_id": "aff2c7c107f445ea3b5f17fbdd894386", "name":"TELEPORT_MODULE"},
    "id": 737
}
response = requests.post(url, headers=headers, data=json.dumps(data))
print(response.text)
# Out:
# {"jsonrpc": "2.0", "id": 737, "error": {"code": 403, "message": "Permission denied (no HTTP access to this method)"}}

# %%
data = {
    "jsonrpc": "2.0",
    "method": "item.location",
    "params": {"world_id": "aff2c7c107f445ea3b5f17fbdd894386", "item":"3c1ad9184d628bd98ab7a637f049578b"},
    "id": 737
}
response = requests.post(url, headers=headers, data=json.dumps(data))
print(response.text)
# Out:
# {"jsonrpc": "2.0", "id": 737, "result": "c46e3f5fb1a82efa54ade682401988ed"}

# %%
data = {
    "jsonrpc": "2.0",
    "method": "room.name",
    "params": {"world_id": "aff2c7c107f445ea3b5f17fbdd894386", "room":"c46e3f5fb1a82efa54ade682401988ed"},
    "id": 737
}
response = requests.post(url, headers=headers, data=json.dumps(data))
print(response.text)
# Out:
# {"jsonrpc": "2.0", "id": 737, "result": "JU_ATRIUM_J04"}

# %%
protagonist.move(world_id='aff2c7c107f445ea3b5f17fbdd894386', room='013b0554136004de1db3c82005194039')

# %% [markdown]
# Items dans la salle indiquée par le géolocator

# %%
data = {
    "jsonrpc": "2.0",
    "method": "protagonist.move",
    "params": {},
    "id": 737
}
response = requests.post(url, headers=headers, data=json.dumps(data))
print(response.text)
# Out:
# {"jsonrpc": "2.0", "id": 737, "error": {"code": -32602, "message": "Invalid params", "data": {"name": "ticket", "reason": "missing argument"}}}

# %%
data = {
    "jsonrpc": "2.0",
    "method": "room.items",
        "params": {"world_id":"807b4a5d685915218c7987708c110cbe", "room":"488aee50c397570f8d460223833eba7f"},
    "id": 737
}
response = requests.post(url, headers=headers, data=json.dumps(data))
print(response.text)
# Out:
# {"jsonrpc": "2.0", "id": 737, "result": ["e5d322e95a29ad9f151f893098a75b61", "582a210e29921bf233ba38936855201d"]}

# %%
data = {
    "jsonrpc": "2.0",
    "method": "item.name",
    "params": {"world_id": "807b4a5d685915218c7987708c110cbe", "item":"e5d322e95a29ad9f151f893098a75b61"},
    "id": 737
}
response = requests.post(url, headers=headers, data=json.dumps(data))
print(response.text)
# Out:
# {"jsonrpc": "2.0", "id": 737, "result": "CHIP_WHISPERER_PRO"}

# %%
data = {
    "jsonrpc": "2.0",
    "method": "item.name",
    "params": {"world_id": "807b4a5d685915218c7987708c110cbe", "item":"582a210e29921bf233ba38936855201d"},
    "id": 737
}
response = requests.post(url, headers=headers, data=json.dumps(data))
print(response.text)
# Out:
# {"jsonrpc": "2.0", "id": 737, "result": "TME_RSA_RELATED"}

# %% [markdown]
# Kerberos

# %%
data = {
    "jsonrpc": "2.0",
    "method": "kerberos.authentication-service",
    "params": {"username": "niccolo"},
    "id": 1
}
response = requests.post(url, headers=headers, data=json.dumps(data))
print(response.text)
# Out:
# {"jsonrpc": "2.0", "id": 1, "result": {"ticket": "U2FsdGVkX1+7Q0teCCjLqs/+JURVtpi6jc+qG4ovs0XXJ/JgB88xRGXaWCei3aEM\nKi2v9l8ulluD5/vQWvi0j1ogLPEK5h8hxVBDV9dQxJ8I4xqDmMm1cn+BNExKqXC+\nRi8UD42BNduXktf5eRm5mm4+8/wVkqN/WFUyrVN5BAU=\n", "key": "U2FsdGVkX1/9IA62WsiRQZ3+afK51f0eLUY7pbJLF5dD76S8qacoxxkng3bv5z+NtEjuzu1oCInp\nUgeYOewJoA==\n"}}

# %%
# Importing required module
import subprocess

subprocess.Popen("""echo "U2FsdGVkX1/9IA62WsiRQZ3+afK51f0eLUY7pbJLF5dD76S8qacoxxkng3bv5z+NtEjuzu1oCInp\nUgeYOewJoA==\n" | openssl enc -aes-128-cbc -d -salt -pbkdf2 -base64 -pass pass:XVdeFranceXV""", shell=True)
# Out:
# <Popen: returncode: None args: 'echo "U2FsdGVkX1/9IA62WsiRQZ3+afK51f0eLUY7pb...>
# 4f2b89321d6e5f9c6bfc0bb74bb9a1b9

# %%
# Importing required module
import subprocess

subprocess.Popen("""echo '{"username": "niccolo", "timestamp": '$(date +%s)'}' | openssl enc -aes-128-cbc -salt -pbkdf2 -base64 -pass pass:4f2b89321d6e5f9c6bfc0bb74bb9a1b9""", shell=True)
# Out:
# <Popen: returncode: None args: 'echo \'{"username": "niccolo", "timestamp": ...>
# U2FsdGVkX1+tpBNpreBxP4upeBsmX7vmFd+kAzRVGYW0lyHsSadz2zuJCjEahZYM
# I2QMsipo3+ZiHVmqZdXwSM61TUozGY4gjfJcCRGM0z4=

# %%
data = {
    "jsonrpc": "2.0",
    "method": "kerberos.ticket-granting-service",
    "params": {"ticket": "U2FsdGVkX1+7Q0teCCjLqs/+JURVtpi6jc+qG4ovs0XXJ/JgB88xRGXaWCei3aEM\nKi2v9l8ulluD5/vQWvi0j1ogLPEK5h8hxVBDV9dQxJ8I4xqDmMm1cn+BNExKqXC+\nRi8UD42BNduXktf5eRm5mm4+8/wVkqN/WFUyrVN5BAU=\n", "authenticator":"""U2FsdGVkX1+tpBNpreBxP4upeBsmX7vmFd+kAzRVGYW0lyHsSadz2zuJCjEahZYM
I2QMsipo3+ZiHVmqZdXwSM61TUozGY4gjfJcCRGM0z4=""", "method":"protagonist.move"},
    "id": 1
}
response = requests.post(url, headers=headers, data=json.dumps(data))
print(response.text)
# Out:
# {"jsonrpc": "2.0", "id": 1, "result": {"ticket": "U2FsdGVkX18lcOlgW3eouDwGE9w90eOBb3J7XbndpfGi1fmrkVxsn7ZMhF9e5DDh\na+80i/3N1MPSb9EATSNKz5m80VS0TweNslTxOQ83ZsB2NsamXsN75Ft79buWZjD2\nKkyehchFye+sIOt2S9iQP2elitreoGy8o208APhVfOA=\n", "key": "U2FsdGVkX18G/xR14aarBT73UPQsVznVpfg6xEAQoUclXb7L6qeJs3WK95nZt59ojX4Of+u9kA4B\nwSIo2A3T6w==\n"}}

# %%
import subprocess

subprocess.Popen("""echo "U2FsdGVkX18G/xR14aarBT73UPQsVznVpfg6xEAQoUclXb7L6qeJs3WK95nZt59ojX4Of+u9kA4B\nwSIo2A3T6w==\n" | openssl enc -aes-128-cbc -d -salt -pbkdf2 -base64 -pass pass:4f2b89321d6e5f9c6bfc0bb74bb9a1b9""", shell=True)
# Out:
# <Popen: returncode: None args: 'echo "U2FsdGVkX18G/xR14aarBT73UPQsVznVpfg6xE...>
# efc71f42339b70d95e786d62dff6563d

# %%
import subprocess

subprocess.Popen("""echo '{"username": "niccolo", "timestamp": '$(date +%s)'}' | openssl enc -aes-128-cbc -salt -pbkdf2 -base64 -pass pass:efc71f42339b70d95e786d62dff6563d""", shell=True)
# Out:
# <Popen: returncode: None args: 'echo \'{"username": "niccolo", "timestamp": ...>
# U2FsdGVkX19WgA2qOGC64PAc5g51eeA1Ik7SLxcMsNlf6Ug18kBi5zybiXGVCIXQ
# k2Ale47czEOyQEzuXInSODmT4u32gMc8a2lBCAqf1WI=

# %%
import subprocess

subprocess.Popen("""echo '{"world_id": "aff2c7c107f445ea3b5f17fbdd894386", "room":"095d6476b6587254bb70c8ed76c22017"}' | openssl enc -aes-128-cbc -salt -pbkdf2 -base64 -pass pass:efc71f42339b70d95e786d62dff6563d""", shell=True)
# Out:
# <Popen: returncode: None args: 'echo \'{"world_id": "aff2c7c107f445ea3b5f17f...>
# U2FsdGVkX1+3qbZEM8GAIdTQ8ZBvLWf/jH1D8m5Wk/qDM5h0336SbS/duj+0YB34
# 5yFK1HaCCKBFUw1i7U0f1ESVtMyWcRWjzy4lMKN/s9NInK7dE6JPC2WirNcg63Sh
# P0fWIaCn5uX2FiE8NOuQDQ==

# %%
data = {
    "jsonrpc": "2.0",
    "method": "protagonist.move",
    "params": {"ticket": "U2FsdGVkX18lcOlgW3eouDwGE9w90eOBb3J7XbndpfGi1fmrkVxsn7ZMhF9e5DDh\na+80i/3N1MPSb9EATSNKz5m80VS0TweNslTxOQ83ZsB2NsamXsN75Ft79buWZjD2\nKkyehchFye+sIOt2S9iQP2elitreoGy8o208APhVfOA=\n", "authenticator":"""U2FsdGVkX19WgA2qOGC64PAc5g51eeA1Ik7SLxcMsNlf6Ug18kBi5zybiXGVCIXQ
k2Ale47czEOyQEzuXInSODmT4u32gMc8a2lBCAqf1WI=""", "encrypted_args":"""U2FsdGVkX1+3qbZEM8GAIdTQ8ZBvLWf/jH1D8m5Wk/qDM5h0336SbS/duj+0YB34
5yFK1HaCCKBFUw1i7U0f1ESVtMyWcRWjzy4lMKN/s9NInK7dE6JPC2WirNcg63Sh
P0fWIaCn5uX2FiE8NOuQDQ==

"""},
    "id": 1
}
response = requests.post(url, headers=headers, data=json.dumps(data))
print(response.text)
# Out:
# {"jsonrpc": "2.0", "id": 1, "result": "U2FsdGVkX19MMF6arHE7a3Wde/8NvSnWNdatpaAV/iVAcAmaiNwFB2XEYOCvh5rh\n"}

# %%
import subprocess

subprocess.Popen("""echo "U2FsdGVkX19MMF6arHE7a3Wde/8NvSnWNdatpaAV/iVAcAmaiNwFB2XEYOCvh5rh\n" | openssl enc -aes-128-cbc -d -salt -pbkdf2 -base64 -pass pass:efc71f42339b70d95e786d62dff6563d""", shell=True)
# Out:
# <Popen: returncode: None args: 'echo "U2FsdGVkX19MMF6arHE7a3Wde/8NvSnWNdatpa...>
# {"result": null}

# %%
import subprocess
